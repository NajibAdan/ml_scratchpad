# %% [markdown]
# # Exercises
# ![image.png](attachment:image.png)
#
# ## Answer
# [[42,-99]
#
#  [4,-3]
#
#  [7,17]
#
#  [99,22]]
#
# ## Proof

# %%
import torch 
import numpy as np 

X_pt = torch.tensor([[42,4,7,99],[-99,-3,17,22]])
X_pt.T
# Out:
# tensor([[ 42, -99],
#         [  4,  -3],
#         [  7,  17],
#         [ 99,  22]])

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ## Answer
#
# [[-25,70]
#
#  [-20,8]]
#
# ## Proof

# %%
X = np.array([[25,10],[-2,1]])
Y = np.array([[-1,7],[10,8]])

X * Y
# Out:
# array([[-25,  70],
#        [-20,   8]])

# %% [markdown]
# ![image.png](attachment:image.png)
#
#
# ## Answer
# 15
#
# ## Proof

# %%
x_pt = torch.tensor([-1,2,-2])
y_pt = torch.tensor([5,10,0])

np.dot(x_pt,y_pt)
# Out:
# 15
