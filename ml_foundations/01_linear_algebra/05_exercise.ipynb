# %% [markdown]
# # Exercises
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Answer
# [25,2,-3,-23]
#
# ## Proof

# %%
import numpy as np
x = np.array([[25],[2],[-3],[-23]])
x
# Out:
# array([[ 25],
#        [  2],
#        [ -3],
#        [-23]])

# %%
x.T
# Out:
# array([[ 25,   2,  -3, -23]])

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Answer
# The dimensions are **(2,4)**
#
# ## Proof

# %%
y = np.array([[42,4,7,99],[-99,-3,17,22]])
y
# Out:
# array([[ 42,   4,   7,  99],
#        [-99,  -3,  17,  22]])

# %%
y.shape
# Out:
# (2, 4)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ## Answer
# The notation is **Y<sub>2,3</sub>**
#
# ## Proof

# %%
y[1,2] # Because it is in zero-indexed
# Out:
# 17
