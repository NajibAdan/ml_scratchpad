# %% [markdown]
# # Exercise
#
# ![image.png](attachment:image.png)
#
# ## Answer
#
# 0\*-1 + 1\*1 + 2\*2  = -1 + 1 + 4 = 4
#
# 3\*-1 + 4\*1 + 5\*2    -3 + 4 + 10  11
#
# 6\*-1 + 7\*1 + 8\*2    -6 + 7 + 16  17
#
# ## Proof
