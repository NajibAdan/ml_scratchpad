# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np

X = np.array([[1,0,0],[0,1,0],[0,0,1]])
X
# Out:
# array([[1, 0, 0],
#        [0, 1, 0],
#        [0, 0, 1]])

# %% [markdown]
# dot product of X<sup>T</sup>Y = 0

# %%
print(np.dot(X[0],X[1]))
print(np.dot(X[1],X[2]))
# Out:
# 0
# 0

# %%
for col in X:
    print(np.linalg.norm(col))
# Out:
# 1.0
# 1.0
# 1.0

# %%
K = np.array([[2/3,1/3,2/3],[-2/3,2/3,1/3],[1/3,2/3,-2/3]])
K
# Out:
# array([[ 0.66666667,  0.33333333,  0.66666667],
#        [-0.66666667,  0.66666667,  0.33333333],
#        [ 0.33333333,  0.66666667, -0.66666667]])

# %%
print(np.dot(K[0],K[1]))
print(np.dot(K[1],K[2]))
# Out:
# 0.0
# 0.0

# %%
for col in K:
    print(np.linalg.norm(col))
# Out:
# 1.0
# 1.0
# 1.0
